# %%
import sys
import numpy as np
from python_speech_features import mfcc
from python_speech_features import logfbank
import python_speech_features
import scipy.io.wavfile as wav
import os
import re

# %%
phone_classes = np.array(['b', 'd', 'g', 'p', 't', 'k', 'dx', 'q', 
                 'jh', 'ch', 's', 'sh', 'z', 'zh', 'f', 'th', 'v', 'dh',
                 'm', 'n', 'ng', 'em', 'en', 'eng', 'nx',
                 'l', 'r', 'w', 'y', 'hh', 'hv', 'el',
                 'iy', 'ih', 'eh', 'ey', 'ae', 'aa', 'aw', 
                 'ay', 'ah', 'ao', 'oy', 'ow', 'uh', 'uw',
                 'ux', 'er', 'ax', 'ix', 'axr', 'ax-h',
                 'pau', 'epi',  
                 'bcl', 'dcl', 'gcl', 'pcl', 'tck', 'kcl', 'tcl',
                 'h', '1', '2'])
print len(phone_classes)

# Constants
SPACE_TOKEN = '<space>'
SPACE_INDEX = 0
FIRST_INDEX = ord('a') - 1  # 0 is reserved to space
# Out:
# 64

# %%
def normalize_mfcc(mfcc):
    means = np.mean(mfcc, 0)
    stds = np.std(mfcc, 0)
    return (mfcc - means)/stds

def add_noise(v):
    n = np.random.normal(scale=0.6, size=v.size)
    v = v + np.reshape(n, v.shape)
    return v

def delta(feat, N):
    """Compute delta features from a feature vector sequence.
    :param feat: A numpy array of size (NUMFRAMES by number of features) containing features. Each row holds 1 feature vector.
    :param N: For each frame, calculate delta features based on preceding and following N frames
    :returns: A numpy array of size (NUMFRAMES by number of features) containing delta features. Each row holds 1 delta feature vector.
    """
    NUMFRAMES = len(feat)
    feat = np.concatenate(([feat[0] for i in range(N)], feat, [feat[-1] for i in range(N)]))
    denom = sum([2*i*i for i in range(1,N+1)])
    dfeat = []
    for j in range(NUMFRAMES):
        dfeat.append(np.sum([n*feat[N+j+n] for n in range(-1*N,N+1)], axis=0)/denom)
    return np.asarray(dfeat)

def convert_mfcc(filename):
    (rate,sig) = wav.read(filename)
    mfcc_feat = mfcc(sig, samplerate=rate)
    
    d = logfbank(sig)
    mfcc_feat = np.concatenate((mfcc_feat, d), axis=1)
    mfcc_feat = normalize_mfcc(mfcc_feat)
    
    mfcc_feat = add_noise(mfcc_feat)
    
#     print mfcc_feat.shape
    assert mfcc_feat.shape[1] == 39
    return mfcc_feat

def read_phn(f):
    temp_phones = np.loadtxt(f, dtype={'names':('start', 'end', 'phone'), 
                            'formats':(np.int32, np.int32, 'S4')})
    
    # Get the length of the phone data
    _, phn_len, _ = temp_phones[-1]    
    phn_len_mill = int(phn_len/160)
  

    # Create an array to store the start and end times of a phone
    phone_times = []
    
    # Convert the string phonemes to class labels
    for i, (s, e, phone) in enumerate(temp_phones):
        a = np.where(phone_classes == phone)[0][0]
        if a <= 60:
            phone_times.append(a)
    phone_times = np.asarray(phone_times)
    phone_times = phone_times.astype(np.uint8)
    return phone_times

def read_txt(target_filename):
    # Readings targets
    with open(target_filename, 'r') as f:
        for line in f.readlines():
            if line[0] == ';':
                continue
            # Get only the words between [a-z] and replace period for none
#             original = ' '.join(line.strip().lower().split(' ')[2:]).replace('.', '', '\'')
            
            original = " ".join(re.findall("[a-z]+", line.strip().lower()))
#             print original
            targets = original.replace(' ', '  ')
            targets = targets.split(' ')

    # Adding blank label
#     print targets
    targets = np.hstack([SPACE_TOKEN if x == '' else list(x) for x in targets])
#     print targets
    # Transform char into index
    targets = np.asarray([SPACE_INDEX if x == SPACE_TOKEN else ord(x) - FIRST_INDEX
                          for x in targets])
    targets = np.maximum(targets, 0)
    return targets

# %%
train_root = "/home/zhihaol/TIMIT/TRAIN/"
test_root = "/home/zhihaol/TIMIT/TEST/"
train_target = "/home/zhihaol/807/TIMIT/train/"
test_target = "/home/zhihaol/807/TIMIT/test/"

# %%
root = train_root
target = train_target
for subdir, dirs, files in os.walk(root):
    for f in files:
        if f.endswith(".PHN"):
            abs_fn = os.path.join(subdir, f)
            print abs_fn
            mfcc_feat = convert_mfcc(abs_fn[:-3] + "wav")
#             phone_times = read_phn(abs_fn)
            txt_target = read_txt(abs_fn[:-3] + "TXT")
            dds = abs_fn.split('/')
            new_name = dds[-3] + '_' + dds[-2] + '_' + dds[-1]
            new_name = new_name[:-4]
            np.save(os.path.join(target, 'mfcc' ,new_name), mfcc_feat.transpose())
#             np.save(os.path.join(target, 'phn' ,new_name), phone_times)
            np.save(os.path.join(target, 'txt' ,new_name), txt_target)
            break
# Out:
# /home/zhihaol/TIMIT/TRAIN/DR6/MBMA1/SI2207.PHN
# /home/zhihaol/TIMIT/TRAIN/DR6/MRMB0/SX51.PHN
# /home/zhihaol/TIMIT/TRAIN/DR6/FRJB0/SA2.PHN
# /home/zhihaol/TIMIT/TRAIN/DR6/MRXB0/SA1.PHN
# /home/zhihaol/TIMIT/TRAIN/DR6/MTXS0/SI1690.PHN
# /home/zhihaol/TIMIT/TRAIN/DR6/MESJ0/SA1.PHN
# /home/zhihaol/TIMIT/TRAIN/DR6/MSDS0/SX357.PHN
# /home/zhihaol/TIMIT/TRAIN/DR6/FSBK0/SX79.PHN
# /home/zhihaol/TIMIT/TRAIN/DR6/MSMR0/SX325.PHN
# /home/zhihaol/TIMIT/TRAIN/DR6/FHXS0/SX355.PHN
# /home/zhihaol/TIMIT/TRAIN/DR6/MKLN0/SI2228.PHN
# /home/zhihaol/TIMIT/TRAIN/DR6/MAJP0/SX354.PHN
# /home/zhihaol/TIMIT/TRAIN/DR6/FLAG0/SX294.PHN
# /home/zhihaol/TIMIT/TRAIN/DR6/MDRD0/SX32.PHN
# /home/zhihaol/TIMIT/TRAIN/DR6/FPAD0/SX446.PHN
# /home/zhihaol/TIMIT/TRAIN/DR6/MSAT1/SX353.PHN
# /home/zhihaol/TIMIT/TRAIN/DR6/FSGF0/SI1557.PHN
# /home/zhihaol/TIMIT/TRAIN/DR6/FTAJ0/SX249.PHN
# /home/zhihaol/TIMIT/TRAIN/DR6/MSVS0/SX308.PHN
# /home/zhihaol/TIMIT/TRAIN/DR6/FJDM2/SI2212.PHN
# /home/zhihaol/TIMIT/TRAIN/DR6/MMDB0/SX357.PHN
# /home/zhihaol/TIMIT/TRAIN/DR6/FAPB0/SX433.PHN
# /home/zhihaol/TIMIT/TRAIN/DR6/MKES0/SI623.PHN
# /home/zhihaol/TIMIT/TRAIN/DR6/FBCH0/SI959.PHN
# /home/zhihaol/TIMIT/TRAIN/DR6/MPGR1/SX329.PHN
# /home/zhihaol/TIMIT/TRAIN/DR6/FKLC1/SX418.PHN
# /home/zhihaol/TIMIT/TRAIN/DR6/MEJL0/SI962.PHN
# /home/zhihaol/TIMIT/TRAIN/DR6/MSJK0/SA1.PHN
# /home/zhihaol/TIMIT/TRAIN/DR6/MJRK0/SX430.PHN
# /home/zhihaol/TIMIT/TRAIN/DR6/FMJU0/SA2.PHN
# /home/zhihaol/TIMIT/TRAIN/DR6/MTJU0/SA1.PHN
# /home/zhihaol/TIMIT/TRAIN/DR6/FSDJ0/SI1115.PHN
# /home/zhihaol/TIMIT/TRAIN/DR6/MABC0/SI2041.PHN
# /home/zhihaol/TIMIT/TRAIN/DR6/MEAL0/SA1.PHN
# /home/zhihaol/TIMIT/TRAIN/DR6/MCAE0/SA2.PHN
# /home/zhihaol/TIMIT/TRAIN/DR1/MTJS0/SA1.PHN
# /home/zhihaol/TIMIT/TRAIN/DR1/FSAH0/SA1.PHN
# /home/zhihaol/TIMIT/TRAIN/DR1/FCJF0/SI1027.PHN
# /home/zhihaol/TIMIT/TRAIN/DR1/MPGH0/SA2.PHN
# /home/zhihaol/TIMIT/TRAIN/DR1/MWAD0/SX162.PHN
# /home/zhihaol/TIMIT/TRAIN/DR1/FDAW0/SA2.PHN
# /home/zhihaol/TIMIT/TRAIN/DR1/FJSP0/SA2.PHN
# /home/zhihaol/TIMIT/TRAIN/DR1/MRSO0/SX309.PHN
# /home/zhihaol/TIMIT/TRAIN/DR1/MRWS0/SX112.PHN
# /home/zhihaol/TIMIT/TRAIN/DR1/MPSW0/SI1697.PHN
# /home/zhihaol/TIMIT/TRAIN/DR1/FDML0/SA1.PHN
# /home/zhihaol/TIMIT/TRAIN/DR1/MDAC0/SI1837.PHN
# /home/zhihaol/TIMIT/TRAIN/DR1/MWAR0/SA2.PHN
# /home/zhihaol/TIMIT/TRAIN/DR1/FVFB0/SX312.PHN
# /home/zhihaol/TIMIT/TRAIN/DR1/FSJK1/SI696.PHN
# /home/zhihaol/TIMIT/TRAIN/DR1/MKLS0/SX177.PHN
# /home/zhihaol/TIMIT/TRAIN/DR1/MTPF0/SX155.PHN
# /home/zhihaol/TIMIT/TRAIN/DR1/MPGR0/SX330.PHN
# /home/zhihaol/TIMIT/TRAIN/DR1/FTBR0/SA2.PHN
# /home/zhihaol/TIMIT/TRAIN/DR1/FMEM0/SA1.PHN
# /home/zhihaol/TIMIT/TRAIN/DR1/MCPM0/SA2.PHN
# /home/zhihaol/TIMIT/TRAIN/DR1/FECD0/SX428.PHN
# /home/zhihaol/TIMIT/TRAIN/DR1/FETB0/SX158.PHN
# /home/zhihaol/TIMIT/TRAIN/DR1/MJWT0/SI1291.PHN
# /home/zhihaol/TIMIT/TRAIN/DR1/FKFB0/SA2.PHN
# /home/zhihaol/TIMIT/TRAIN/DR1/MRDD0/SI2310.PHN
# /home/zhihaol/TIMIT/TRAIN/DR1/MDPK0/SI1683.PHN
# /home/zhihaol/TIMIT/TRAIN/DR1/MKLW0/SX311.PHN
# /home/zhihaol/TIMIT/TRAIN/DR1/MGRL0/SI2127.PHN
# /home/zhihaol/TIMIT/TRAIN/DR1/FSMA0/SX91.PHN
# /home/zhihaol/TIMIT/TRAIN/DR1/MTRR0/SX18.PHN
# /home/zhihaol/TIMIT/TRAIN/DR1/MEDR0/SI1374.PHN
# /home/zhihaol/TIMIT/TRAIN/DR1/FVMH0/SX26.PHN
# /home/zhihaol/TIMIT/TRAIN/DR1/MRCG0/SX78.PHN
# /home/zhihaol/TIMIT/TRAIN/DR1/MJEB1/SX117.PHN
# /home/zhihaol/TIMIT/TRAIN/DR1/MRAI0/SI2052.PHN
# /home/zhihaol/TIMIT/TRAIN/DR1/MMRP0/SX414.PHN
# /home/zhihaol/TIMIT/TRAIN/DR1/MMGG0/SI1709.PHN
# /home/zhihaol/TIMIT/TRAIN/DR5/MREW1/SA1.PHN
# /home/zhihaol/TIMIT/TRAIN/DR5/MRVG0/SI510.PHN
# /home/zhihaol/TIMIT/TRAIN/DR5/FSMS1/SX244.PHN
# /home/zhihaol/TIMIT/TRAIN/DR5/FDMY0/SI1197.PHN
# /home/zhihaol/TIMIT/TRAIN/DR5/MRML0/SX341.PHN
# /home/zhihaol/TIMIT/TRAIN/DR5/MDWH0/SA2.PHN
# /home/zhihaol/TIMIT/TRAIN/DR5/MRAV0/SA1.PHN
# /home/zhihaol/TIMIT/TRAIN/DR5/FLJG0/SX351.PHN
# /home/zhihaol/TIMIT/TRAIN/DR5/MFER0/SA2.PHN
# /home/zhihaol/TIMIT/TRAIN/DR5/MMCC0/SX348.PHN
# /home/zhihaol/TIMIT/TRAIN/DR5/MJPG0/SI1821.PHN
# /home/zhihaol/TIMIT/TRAIN/DR5/FLOD0/SI1287.PHN
# /home/zhihaol/TIMIT/TRAIN/DR5/MJXA0/SA1.PHN
# /home/zhihaol/TIMIT/TRAIN/DR5/FGDP0/SX88.PHN
# /home/zhihaol/TIMIT/TRAIN/DR5/FBMH0/SI1766.PHN
# /home/zhihaol/TIMIT/TRAIN/DR5/FPMY0/SA1.PHN
# /home/zhihaol/TIMIT/TRAIN/DR5/MCLM0/SA1.PHN
# /home/zhihaol/TIMIT/TRAIN/DR5/FDTD0/SI931.PHN
# /home/zhihaol/TIMIT/TRAIN/DR5/MRLD0/SX154.PHN
# /home/zhihaol/TIMIT/TRAIN/DR5/FTLG0/SA1.PHN
# /home/zhihaol/TIMIT/TRAIN/DR5/MWEM0/SX420.PHN
# /home/zhihaol/TIMIT/TRAIN/DR5/MHIT0/SI1613.PHN
# /home/zhihaol/TIMIT/TRAIN/DR5/MDSJ0/SX292.PHN
# /home/zhihaol/TIMIT/TRAIN/DR5/FJXM0/SA2.PHN
# /home/zhihaol/TIMIT/TRAIN/DR5/FCDR1/SX196.PHN
# /home/zhihaol/TIMIT/TRAIN/DR5/MSRR0/SX231.PHN
# /home/zhihaol/TIMIT/TRAIN/DR5/MPMB0/SX151.PHN
# /home/zhihaol/TIMIT/TRAIN/DR5/FBJL0/SA1.PHN
# /home/zhihaol/TIMIT/TRAIN/DR5/MWCH0/SA2.PHN
# /home/zhihaol/TIMIT/TRAIN/DR5/MGES0/SA1.PHN
# /home/zhihaol/TIMIT/TRAIN/DR5/MMDM1/SA1.PHN
# /home/zhihaol/TIMIT/TRAIN/DR5/FKKH0/SX30.PHN
# /home/zhihaol/TIMIT/TRAIN/DR5/MJRG0/SI1366.PHN
# /home/zhihaol/TIMIT/TRAIN/DR5/MMWB0/SI1619.PHN
# /home/zhihaol/TIMIT/TRAIN/DR5/MJFH0/SX297.PHN
# /home/zhihaol/TIMIT/TRAIN/DR5/MHMG0/SI1995.PHN
# /home/zhihaol/TIMIT/TRAIN/DR5/MTMT0/SA2.PHN
# /home/zhihaol/TIMIT/TRAIN/DR5/FLJA0/SI1708.PHN
# /home/zhihaol/TIMIT/TRAIN/DR5/FLMK0/SI2295.PHN
# /home/zhihaol/TIMIT/TRAIN/DR5/MEGJ0/SI1337.PHN
# /home/zhihaol/TIMIT/TRAIN/DR5/FEAR0/SI1882.PHN
# /home/zhihaol/TIMIT/TRAIN/DR5/MBGT0/SI711.PHN
# /home/zhihaol/TIMIT/TRAIN/DR5/MWSH0/SX166.PHN
# /home/zhihaol/TIMIT/TRAIN/DR5/MCHL0/SX177.PHN
# /home/zhihaol/TIMIT/TRAIN/DR5/MSEM1/SA2.PHN
# /home/zhihaol/TIMIT/TRAIN/DR5/MDAS0/SA2.PHN
# /home/zhihaol/TIMIT/TRAIN/DR5/MSAS0/SA2.PHN
# /home/zhihaol/TIMIT/TRAIN/DR5/MJWG0/SI813.PHN
# /home/zhihaol/TIMIT/TRAIN/DR5/MEWM0/SI718.PHN
# /home/zhihaol/TIMIT/TRAIN/DR5/MSDH0/SX80.PHN
# /home/zhihaol/TIMIT/TRAIN/DR5/MVLO0/SI517.PHN
# /home/zhihaol/TIMIT/TRAIN/DR5/MJDM0/SA1.PHN
# /home/zhihaol/TIMIT/TRAIN/DR5/MMAB1/SI864.PHN
# /home/zhihaol/TIMIT/TRAIN/DR5/FSDC0/SX52.PHN
# /home/zhihaol/TIMIT/TRAIN/DR5/MRKM0/SA2.PHN
# /home/zhihaol/TIMIT/TRAIN/DR5/FSAG0/SI1323.PHN
# /home/zhihaol/TIMIT/TRAIN/DR5/MWAC0/SI971.PHN
# /home/zhihaol/TIMIT/TRAIN/DR5/FMPG0/SI972.PHN
# /home/zhihaol/TIMIT/TRAIN/DR5/FSKP0/SI1728.PHN
# /home/zhihaol/TIMIT/TRAIN/DR5/MGSH0/SI1806.PHN
# /home/zhihaol/TIMIT/TRAIN/DR5/MRAM0/SX375.PHN
# /home/zhihaol/TIMIT/TRAIN/DR5/MDHL0/SX89.PHN
# /home/zhihaol/TIMIT/TRAIN/DR5/FSJG0/SI2200.PHN
# /home/zhihaol/TIMIT/TRAIN/DR5/MMVP0/SI1914.PHN
# /home/zhihaol/TIMIT/TRAIN/DR5/FSMM0/SX144.PHN
# /home/zhihaol/TIMIT/TRAIN/DR5/FTBW0/SX175.PHN
# /home/zhihaol/TIMIT/TRAIN/DR5/FGMB0/SA2.PHN
# /home/zhihaol/TIMIT/TRAIN/DR5/FEXM0/SX111.PHN
# /home/zhihaol/TIMIT/TRAIN/DR5/MTAT0/SX120.PHN
# /home/zhihaol/TIMIT/TRAIN/DR5/MTDP0/SI1521.PHN
# /home/zhihaol/TIMIT/TRAIN/DR2/FKAA0/SI578.PHN
# /home/zhihaol/TIMIT/TRAIN/DR2/MTJG0/SI1520.PHN
# /home/zhihaol/TIMIT/TRAIN/DR2/FCAJ0/SA1.PHN
# /home/zhihaol/TIMIT/TRAIN/DR2/MRGS0/SI726.PHN
# /home/zhihaol/TIMIT/TRAIN/DR2/MRFK0/SX176.PHN
# /home/zhihaol/TIMIT/TRAIN/DR2/FEAC0/SX345.PHN
# /home/zhihaol/TIMIT/TRAIN/DR2/FTMG0/SA2.PHN
# /home/zhihaol/TIMIT/TRAIN/DR2/MRMS0/SI2100.PHN
# /home/zhihaol/TIMIT/TRAIN/DR2/MDEM0/SX248.PHN
# /home/zhihaol/TIMIT/TRAIN/DR2/MDMT0/SX212.PHN
# /home/zhihaol/TIMIT/TRAIN/DR2/MDSS0/SX81.PHN
# /home/zhihaol/TIMIT/TRAIN/DR2/MWSB0/SX96.PHN
# /home/zhihaol/TIMIT/TRAIN/DR2/FSKL0/SX89.PHN
# /home/zhihaol/TIMIT/TRAIN/DR2/MDBP0/SX168.PHN
# /home/zhihaol/TIMIT/TRAIN/DR2/MJMA0/SA1.PHN
# /home/zhihaol/TIMIT/TRAIN/DR2/MRCW0/SX381.PHN
# /home/zhihaol/TIMIT/TRAIN/DR2/MRJM1/SI1298.PHN
# /home/zhihaol/TIMIT/TRAIN/DR2/MTAT1/SA1.PHN
# /home/zhihaol/TIMIT/TRAIN/DR2/MRLJ0/SA1.PHN
# /home/zhihaol/TIMIT/TRAIN/DR2/MJRP0/SA1.PHN
# /home/zhihaol/TIMIT/TRAIN/DR2/MDLB0/SX316.PHN
# /home/zhihaol/TIMIT/TRAIN/DR2/MARC0/SI1188.PHN
# /home/zhihaol/TIMIT/TRAIN/DR2/MKAJ0/SX334.PHN
# /home/zhihaol/TIMIT/TRAIN/DR2/MPRB0/SA1.PHN
# /home/zhihaol/TIMIT/TRAIN/DR2/FHLM0/SX210.PHN
# /home/zhihaol/TIMIT/TRAIN/DR2/MRJH0/SX439.PHN
# /home/zhihaol/TIMIT/TRAIN/DR2/FMKF0/SA1.PHN
# /home/zhihaol/TIMIT/TRAIN/DR2/MDPS0/SX359.PHN
# /home/zhihaol/TIMIT/TRAIN/DR2/MJAE0/SX174.PHN
# /home/zhihaol/TIMIT/TRAIN/DR2/FLMC0/SI1372.PHN
# /home/zhihaol/TIMIT/TRAIN/DR2/FSRH0/SA2.PHN
# /home/zhihaol/TIMIT/TRAIN/DR2/MPPC0/SA1.PHN
# /home/zhihaol/TIMIT/TRAIN/DR2/MBJV0/SI1247.PHN
# /home/zhihaol/TIMIT/TRAIN/DR2/FDXW0/SA1.PHN
# /home/zhihaol/TIMIT/TRAIN/DR2/MRLR0/SX26.PHN
# /home/zhihaol/TIMIT/TRAIN/DR2/MTDB0/SI1401.PHN
# /home/zhihaol/TIMIT/TRAIN/DR2/FDAS1/SA1.PHN
# /home/zhihaol/TIMIT/TRAIN/DR2/MJBG0/SI1232.PHN
# /home/zhihaol/TIMIT/TRAIN/DR2/MZMB0/SI1796.PHN
# /home/zhihaol/TIMIT/TRAIN/DR2/FJKL0/SA1.PHN
# /home/zhihaol/TIMIT/TRAIN/DR2/FPJF0/SX352.PHN
# /home/zhihaol/TIMIT/TRAIN/DR2/FRLL0/SA2.PHN
# /home/zhihaol/TIMIT/TRAIN/DR2/MRJT0/SX418.PHN
# /home/zhihaol/TIMIT/TRAIN/DR2/MJPM0/SX18.PHN
# /home/zhihaol/TIMIT/TRAIN/DR2/MMAG0/SA2.PHN
# /home/zhihaol/TIMIT/TRAIN/DR2/MCTM0/SX180.PHN
# /home/zhihaol/TIMIT/TRAIN/DR2/FMJB0/SX97.PHN
# /home/zhihaol/TIMIT/TRAIN/DR2/FMMH0/SA1.PHN
# /home/zhihaol/TIMIT/TRAIN/DR2/MSAT0/SI896.PHN
# /home/zhihaol/TIMIT/TRAIN/DR2/MTBC0/SA2.PHN
# /home/zhihaol/TIMIT/TRAIN/DR2/FCMM0/SI1083.PHN
# /home/zhihaol/TIMIT/TRAIN/DR2/MJDE0/SI1120.PHN
# /home/zhihaol/TIMIT/TRAIN/DR2/MJMD0/SI1028.PHN
# /home/zhihaol/TIMIT/TRAIN/DR2/MJEB0/SA2.PHN
# /home/zhihaol/TIMIT/TRAIN/DR2/MMDS0/SX353.PHN
# /home/zhihaol/TIMIT/TRAIN/DR2/FAJW0/SX3.PHN
# /home/zhihaol/TIMIT/TRAIN/DR2/FDNC0/SX108.PHN
# /home/zhihaol/TIMIT/TRAIN/DR2/MMGK0/SI692.PHN
# /home/zhihaol/TIMIT/TRAIN/DR2/MKDT0/SA1.PHN
# /home/zhihaol/TIMIT/TRAIN/DR2/MEFG0/SA2.PHN
# /home/zhihaol/TIMIT/TRAIN/DR2/FLMA0/SX253.PHN
# /home/zhihaol/TIMIT/TRAIN/DR2/MDWD0/SX180.PHN
# /home/zhihaol/TIMIT/TRAIN/DR2/MHRM0/SX238.PHN
# /home/zhihaol/TIMIT/TRAIN/DR2/FCYL0/SI1297.PHN
# /home/zhihaol/TIMIT/TRAIN/DR2/MRHL0/SX345.PHN
# /home/zhihaol/TIMIT/TRAIN/DR2/MKJO0/SX257.PHN
# /home/zhihaol/TIMIT/TRAIN/DR2/MCEW0/SI812.PHN
# /home/zhihaol/TIMIT/TRAIN/DR2/MJHI0/SX158.PHN
# /home/zhihaol/TIMIT/TRAIN/DR2/FSCN0/SX266.PHN
# /home/zhihaol/TIMIT/TRAIN/DR2/MRAB0/SX324.PHN
# /home/zhihaol/TIMIT/TRAIN/DR2/MMXS0/SA2.PHN
# /home/zhihaol/TIMIT/TRAIN/DR2/MRJM0/SA1.PHN
# /home/zhihaol/TIMIT/TRAIN/DR2/MKAH0/SX268.PHN
# /home/zhihaol/TIMIT/TRAIN/DR2/FAEM0/SX42.PHN
# /home/zhihaol/TIMIT/TRAIN/DR2/MDLC2/SX354.PHN
# /home/zhihaol/TIMIT/TRAIN/DR2/MMAA0/SA1.PHN
# /home/zhihaol/TIMIT/TRAIN/DR8/MMLM0/SI1527.PHN
# /home/zhihaol/TIMIT/TRAIN/DR8/FPLS0/SX330.PHN
# /home/zhihaol/TIMIT/TRAIN/DR8/MTCS0/SI2265.PHN
# /home/zhihaol/TIMIT/TRAIN/DR8/MEJS0/SA2.PHN
# /home/zhihaol/TIMIT/TRAIN/DR8/MMPM0/SX71.PHN
# /home/zhihaol/TIMIT/TRAIN/DR8/MKDD0/SI1567.PHN
# /home/zhihaol/TIMIT/TRAIN/DR8/FKLH0/SA1.PHN
# /home/zhihaol/TIMIT/TRAIN/DR8/FCLT0/SX358.PHN
# /home/zhihaol/TIMIT/TRAIN/DR8/FNKL0/SA2.PHN
# /home/zhihaol/TIMIT/TRAIN/DR8/MMEA0/SA1.PHN
# /home/zhihaol/TIMIT/TRAIN/DR8/MCXM0/SI721.PHN
# /home/zhihaol/TIMIT/TRAIN/DR8/MBSB0/SX93.PHN
# /home/zhihaol/TIMIT/TRAIN/DR8/MRLK0/SX213.PHN
# /home/zhihaol/TIMIT/TRAIN/DR8/MRDM0/SX155.PHN
# /home/zhihaol/TIMIT/TRAIN/DR8/MMWS0/SI1518.PHN
# /home/zhihaol/TIMIT/TRAIN/DR8/MKRG0/SX31.PHN
# /home/zhihaol/TIMIT/TRAIN/DR8/MBCG0/SX147.PHN
# /home/zhihaol/TIMIT/TRAIN/DR8/FBCG1/SX352.PHN
# /home/zhihaol/TIMIT/TRAIN/DR8/MRRE0/SX344.PHN
# /home/zhihaol/TIMIT/TRAIN/DR8/FMBG0/SX440.PHN
# /home/zhihaol/TIMIT/TRAIN/DR8/FJRB0/SX402.PHN
# /home/zhihaol/TIMIT/TRAIN/DR8/FCEG0/SA2.PHN
# /home/zhihaol/TIMIT/TRAIN/DR7/MGAR0/SI1212.PHN
# /home/zhihaol/TIMIT/TRAIN/DR7/MRMG0/SX90.PHN
# /home/zhihaol/TIMIT/TRAIN/DR7/FJHK0/SX212.PHN
# /home/zhihaol/TIMIT/TRAIN/DR7/FMKC0/SA1.PHN
# /home/zhihaol/TIMIT/TRAIN/DR7/MRPC1/SA2.PHN
# /home/zhihaol/TIMIT/TRAIN/DR7/MRLJ1/SX141.PHN
# /home/zhihaol/TIMIT/TRAIN/DR7/MTMN0/SI582.PHN
# /home/zhihaol/TIMIT/TRAIN/DR7/MSAH1/SA1.PHN
# /home/zhihaol/TIMIT/TRAIN/DR7/MAEO0/SX246.PHN
# /home/zhihaol/TIMIT/TRAIN/DR7/MTWH1/SX342.PHN
# /home/zhihaol/TIMIT/TRAIN/DR7/MPAR0/SA1.PHN
# /home/zhihaol/TIMIT/TRAIN/DR7/FLEH0/SI1051.PHN
# /home/zhihaol/TIMIT/TRAIN/DR7/MRMH0/SX31.PHN
# /home/zhihaol/TIMIT/TRAIN/DR7/MBBR0/SX425.PHN
# /home/zhihaol/TIMIT/TRAIN/DR7/MKAG0/SX259.PHN
# /home/zhihaol/TIMIT/TRAIN/DR7/MKLR0/SA2.PHN
# /home/zhihaol/TIMIT/TRAIN/DR7/MTKD0/SI1817.PHN
# /home/zhihaol/TIMIT/TRAIN/DR7/MJFR0/SA2.PHN
# /home/zhihaol/TIMIT/TRAIN/DR7/FJEN0/SI2307.PHN
# /home/zhihaol/TIMIT/TRAIN/DR7/FPAB1/SX301.PHN
# /home/zhihaol/TIMIT/TRAIN/DR7/MDLR1/SX219.PHN
# /home/zhihaol/TIMIT/TRAIN/DR7/FCRZ0/SA1.PHN
# /home/zhihaol/TIMIT/TRAIN/DR7/MJAI0/SA1.PHN
# /home/zhihaol/TIMIT/TRAIN/DR7/MDLC1/SX355.PHN
# /home/zhihaol/TIMIT/TRAIN/DR7/MTAB0/SI1572.PHN
# /home/zhihaol/TIMIT/TRAIN/DR7/FMAH1/SX69.PHN
# /home/zhihaol/TIMIT/TRAIN/DR7/MVRW0/SI2115.PHN
# /home/zhihaol/TIMIT/TRAIN/DR7/MDCM0/SA2.PHN
# /home/zhihaol/TIMIT/TRAIN/DR7/MFXV0/SA2.PHN
# /home/zhihaol/TIMIT/TRAIN/DR7/MMWS1/SA1.PHN
# /home/zhihaol/TIMIT/TRAIN/DR7/MGAK0/SA1.PHN
# /home/zhihaol/TIMIT/TRAIN/DR7/MDKS0/SX256.PHN
# /home/zhihaol/TIMIT/TRAIN/DR7/MHXL0/SI1772.PHN
# /home/zhihaol/TIMIT/TRAIN/DR7/MBAR0/SX149.PHN
# /home/zhihaol/TIMIT/TRAIN/DR7/FSPM0/SX341.PHN
# /home/zhihaol/TIMIT/TRAIN/DR7/MNTW0/SX348.PHN
# /home/zhihaol/TIMIT/TRAIN/DR7/MWRP0/SI1525.PHN
# /home/zhihaol/TIMIT/TRAIN/DR7/MKDB0/SX332.PHN
# /home/zhihaol/TIMIT/TRAIN/DR7/MTPR0/SX250.PHN
# /home/zhihaol/TIMIT/TRAIN/DR7/FKSR0/SI1747.PHN
# /home/zhihaol/TIMIT/TRAIN/DR7/MDLM0/SA2.PHN
# /home/zhihaol/TIMIT/TRAIN/DR7/MBOM0/SX311.PHN
# /home/zhihaol/TIMIT/TRAIN/DR7/MDLR0/SX423.PHN
# /home/zhihaol/TIMIT/TRAIN/DR7/MDED0/SI1170.PHN
# /home/zhihaol/TIMIT/TRAIN/DR7/MSES0/SX149.PHN
# /home/zhihaol/TIMIT/TRAIN/DR7/MGAW0/SI1165.PHN
# /home/zhihaol/TIMIT/TRAIN/DR7/MTER0/SI1157.PHN
# /home/zhihaol/TIMIT/TRAIN/DR7/MPFU0/SI628.PHN
# /home/zhihaol/TIMIT/TRAIN/DR7/MMDG0/SX160.PHN
# /home/zhihaol/TIMIT/TRAIN/DR7/MJJM0/SX107.PHN
# /home/zhihaol/TIMIT/TRAIN/DR7/MTML0/SX165.PHN
# /home/zhihaol/TIMIT/TRAIN/DR7/MBML0/SI539.PHN
# /home/zhihaol/TIMIT/TRAIN/DR7/MHBS0/SA2.PHN
# /home/zhihaol/TIMIT/TRAIN/DR7/FBLV0/SI1058.PHN
# /home/zhihaol/TIMIT/TRAIN/DR7/MTLC0/SI1477.PHN
# /home/zhihaol/TIMIT/TRAIN/DR7/FJRP1/SX262.PHN
# /home/zhihaol/TIMIT/TRAIN/DR7/MCLK0/SI1660.PHN
# /home/zhihaol/TIMIT/TRAIN/DR7/FCJS0/SA2.PHN
# /home/zhihaol/TIMIT/TRAIN/DR7/MWRE0/SX337.PHN
# /home/zhihaol/TIMIT/TRAIN/DR7/MADD0/SI538.PHN
# /home/zhihaol/TIMIT/TRAIN/DR7/MFXS0/SI2225.PHN
# /home/zhihaol/TIMIT/TRAIN/DR7/MJRA0/SI1236.PHN
# /home/zhihaol/TIMIT/TRAIN/DR7/MREM0/SX61.PHN
# /home/zhihaol/TIMIT/TRAIN/DR7/FVKB0/SA1.PHN
# /home/zhihaol/TIMIT/TRAIN/DR7/MSDB0/SX377.PHN
# /home/zhihaol/TIMIT/TRAIN/DR7/FPAC0/SI1921.PHN
# /home/zhihaol/TIMIT/TRAIN/DR7/MBTH0/SA2.PHN
# /home/zhihaol/TIMIT/TRAIN/DR7/MDPB0/SI2126.PHN
# /home/zhihaol/TIMIT/TRAIN/DR7/FLET0/SA1.PHN
# /home/zhihaol/TIMIT/TRAIN/DR7/FREH0/SI685.PHN
# /home/zhihaol/TIMIT/TRAIN/DR7/MGSL0/SI534.PHN
# /home/zhihaol/TIMIT/TRAIN/DR7/MJDG0/SA2.PHN
# /home/zhihaol/TIMIT/TRAIN/DR7/FKDE0/SA2.PHN
# /home/zhihaol/TIMIT/TRAIN/DR7/MCTH0/SA2.PHN
# /home/zhihaol/TIMIT/TRAIN/DR7/FJSK0/SI2312.PHN
# /home/zhihaol/TIMIT/TRAIN/DR7/MAFM0/SI2199.PHN
# /home/zhihaol/TIMIT/TRAIN/DR7/MCRE0/SX131.PHN
# /home/zhihaol/TIMIT/TRAIN/DR3/FPAZ0/SX153.PHN
# /home/zhihaol/TIMIT/TRAIN/DR3/MHJB0/SX27.PHN
# /home/zhihaol/TIMIT/TRAIN/DR3/MRDS0/SA1.PHN
# /home/zhihaol/TIMIT/TRAIN/DR3/FGRW0/SX432.PHN
# /home/zhihaol/TIMIT/TRAIN/DR3/MRWA0/SI2233.PHN
# /home/zhihaol/TIMIT/TRAIN/DR3/FMJF0/SA1.PHN
# /home/zhihaol/TIMIT/TRAIN/DR3/MDNS0/SX291.PHN
# /home/zhihaol/TIMIT/TRAIN/DR3/MRJB1/SI2021.PHN
# /home/zhihaol/TIMIT/TRAIN/DR3/FJLR0/SX61.PHN
# /home/zhihaol/TIMIT/TRAIN/DR3/FGCS0/SA1.PHN
# /home/zhihaol/TIMIT/TRAIN/DR3/MJDA0/SX221.PHN
# /home/zhihaol/TIMIT/TRAIN/DR3/MJKR0/SX31.PHN
# /home/zhihaol/TIMIT/TRAIN/DR3/MDDC0/SI789.PHN
# /home/zhihaol/TIMIT/TRAIN/DR3/MJJB0/SX239.PHN
# /home/zhihaol/TIMIT/TRAIN/DR3/MCDD0/SI2143.PHN
# /home/zhihaol/TIMIT/TRAIN/DR3/MFMC0/SX322.PHN
# /home/zhihaol/TIMIT/TRAIN/DR3/MDLC0/SA2.PHN
# /home/zhihaol/TIMIT/TRAIN/DR3/MADC0/SA1.PHN
# /home/zhihaol/TIMIT/TRAIN/DR3/MDBB1/SX196.PHN
# /home/zhihaol/TIMIT/TRAIN/DR3/FSJS0/SX271.PHN
# /home/zhihaol/TIMIT/TRAIN/DR3/MREH1/SI969.PHN
# /home/zhihaol/TIMIT/TRAIN/DR3/FSKC0/SX66.PHN
# /home/zhihaol/TIMIT/TRAIN/DR3/MWDK0/SI1436.PHN
# /home/zhihaol/TIMIT/TRAIN/DR3/FCMG0/SX342.PHN
# /home/zhihaol/TIMIT/TRAIN/DR3/MGAF0/SX292.PHN
# /home/zhihaol/TIMIT/TRAIN/DR3/MVJH0/SX116.PHN
# /home/zhihaol/TIMIT/TRAIN/DR3/MTLB0/SX324.PHN
# /home/zhihaol/TIMIT/TRAIN/DR3/MMAM0/SX157.PHN
# /home/zhihaol/TIMIT/TRAIN/DR3/MMAR0/SX256.PHN
# /home/zhihaol/TIMIT/TRAIN/DR3/MKLS1/SA2.PHN
# /home/zhihaol/TIMIT/TRAIN/DR3/MTKP0/SI1023.PHN
# /home/zhihaol/TIMIT/TRAIN/DR3/FCKE0/SA1.PHN
# /home/zhihaol/TIMIT/TRAIN/DR3/MWGR0/SI976.PHN
# /home/zhihaol/TIMIT/TRAIN/DR3/MREE0/SX294.PHN
# /home/zhihaol/TIMIT/TRAIN/DR3/MCDC0/SA2.PHN
# /home/zhihaol/TIMIT/TRAIN/DR3/MPRD0/SX171.PHN
# /home/zhihaol/TIMIT/TRAIN/DR3/MDEF0/SX123.PHN
# /home/zhihaol/TIMIT/TRAIN/DR3/MJRH1/SX154.PHN
# /home/zhihaol/TIMIT/TRAIN/DR3/MTPG0/SI1383.PHN
# /home/zhihaol/TIMIT/TRAIN/DR3/FSJW0/SX433.PHN
# /home/zhihaol/TIMIT/TRAIN/DR3/FALK0/SI658.PHN
# /home/zhihaol/TIMIT/TRAIN/DR3/MCAL0/SA2.PHN
# /home/zhihaol/TIMIT/TRAIN/DR3/MHMR0/SA1.PHN
# /home/zhihaol/TIMIT/TRAIN/DR3/MTPP0/SX428.PHN
# /home/zhihaol/TIMIT/TRAIN/DR3/MJLG1/SX292.PHN
# /home/zhihaol/TIMIT/TRAIN/DR3/MILB0/SA2.PHN
# /home/zhihaol/TIMIT/TRAIN/DR3/FJLG0/SI2306.PHN
# /home/zhihaol/TIMIT/TRAIN/DR3/FDJH0/SX215.PHN
# /home/zhihaol/TIMIT/TRAIN/DR3/MDHS0/SA2.PHN
# /home/zhihaol/TIMIT/TRAIN/DR3/FLJD0/SX76.PHN
# /home/zhihaol/TIMIT/TRAIN/DR3/MDLH0/SA1.PHN
# /home/zhihaol/TIMIT/TRAIN/DR3/MDTB0/SX210.PHN
# /home/zhihaol/TIMIT/TRAIN/DR3/MRBC0/SI1859.PHN
# /home/zhihaol/TIMIT/TRAIN/DR3/FLAC0/SI2161.PHN
# /home/zhihaol/TIMIT/TRAIN/DR3/MMEB0/SX367.PHN
# /home/zhihaol/TIMIT/TRAIN/DR3/FDFB0/SI1948.PHN
# /home/zhihaol/TIMIT/TRAIN/DR3/MRTJ0/SI772.PHN
# /home/zhihaol/TIMIT/TRAIN/DR3/MDJM0/SX285.PHN
# /home/zhihaol/TIMIT/TRAIN/DR3/FEME0/SI1505.PHN
# /home/zhihaol/TIMIT/TRAIN/DR3/MDWM0/SX376.PHN
# /home/zhihaol/TIMIT/TRAIN/DR3/MAKB0/SI1646.PHN
# /home/zhihaol/TIMIT/TRAIN/DR3/FSLS0/SX66.PHN
# /home/zhihaol/TIMIT/TRAIN/DR3/FNTB0/SX33.PHN
# /home/zhihaol/TIMIT/TRAIN/DR3/MBEF0/SI651.PHN
# /home/zhihaol/TIMIT/TRAIN/DR3/MMSM0/SX386.PHN
# /home/zhihaol/TIMIT/TRAIN/DR3/MMJB1/SX148.PHN
# /home/zhihaol/TIMIT/TRAIN/DR3/MCEF0/SX325.PHN
# /home/zhihaol/TIMIT/TRAIN/DR3/MDSS1/SX337.PHN
# /home/zhihaol/TIMIT/TRAIN/DR3/MAPV0/SX123.PHN
# /home/zhihaol/TIMIT/TRAIN/DR3/FLTM0/SI1070.PHN
# /home/zhihaol/TIMIT/TRAIN/DR3/MAKR0/SA2.PHN
# /home/zhihaol/TIMIT/TRAIN/DR3/MTJM0/SX416.PHN
# /home/zhihaol/TIMIT/TRAIN/DR3/MLNS0/SI2037.PHN
# /home/zhihaol/TIMIT/TRAIN/DR3/MRTC0/SA2.PHN
# /home/zhihaol/TIMIT/TRAIN/DR3/MSFV0/SA2.PHN
# /home/zhihaol/TIMIT/TRAIN/DR3/MKXL0/SX105.PHN
# /home/zhihaol/TIMIT/TRAIN/DR4/MRGM0/SI1792.PHN
# /home/zhihaol/TIMIT/TRAIN/DR4/MCDR0/SI524.PHN
# /home/zhihaol/TIMIT/TRAIN/DR4/MRAB1/SI2108.PHN
# /home/zhihaol/TIMIT/TRAIN/DR4/MGAG0/SX61.PHN
# /home/zhihaol/TIMIT/TRAIN/DR4/MCSS0/SX390.PHN
# /home/zhihaol/TIMIT/TRAIN/DR4/MJRH0/SX135.PHN
# /home/zhihaol/TIMIT/TRAIN/DR4/MTRC0/SI993.PHN
# /home/zhihaol/TIMIT/TRAIN/DR4/FBAS0/SX307.PHN
# /home/zhihaol/TIMIT/TRAIN/DR4/MFRM0/SI1155.PHN
# /home/zhihaol/TIMIT/TRAIN/DR4/MJWS0/SX423.PHN
# /home/zhihaol/TIMIT/TRAIN/DR4/MJJJ0/SA1.PHN
# /home/zhihaol/TIMIT/TRAIN/DR4/MAEB0/SX180.PHN
# /home/zhihaol/TIMIT/TRAIN/DR4/MBWP0/SX259.PHN
# /home/zhihaol/TIMIT/TRAIN/DR4/MKAM0/SI1316.PHN
# /home/zhihaol/TIMIT/TRAIN/DR4/MLJC0/SI595.PHN
# /home/zhihaol/TIMIT/TRAIN/DR4/MTRT0/SX57.PHN
# /home/zhihaol/TIMIT/TRAIN/DR4/FEEH0/SX392.PHN
# /home/zhihaol/TIMIT/TRAIN/DR4/MPRK0/SX287.PHN
# /home/zhihaol/TIMIT/TRAIN/DR4/FSAK0/SA1.PHN
# /home/zhihaol/TIMIT/TRAIN/DR4/MPRT0/SI580.PHN
# /home/zhihaol/TIMIT/TRAIN/DR4/MSMS0/SI1433.PHN
# /home/zhihaol/TIMIT/TRAIN/DR4/MLSH0/SA2.PHN
# /home/zhihaol/TIMIT/TRAIN/DR4/MLBC0/SI1239.PHN
# /home/zhihaol/TIMIT/TRAIN/DR4/MJAC0/SI701.PHN
# /home/zhihaol/TIMIT/TRAIN/DR4/FJWB1/SX435.PHN
# /home/zhihaol/TIMIT/TRAIN/DR4/FKLC0/SX355.PHN
# /home/zhihaol/TIMIT/TRAIN/DR4/MTQC0/SA1.PHN
# /home/zhihaol/TIMIT/TRAIN/DR4/MSTF0/SX316.PHN
# /home/zhihaol/TIMIT/TRAIN/DR4/MMBS0/SX251.PHN
# /home/zhihaol/TIMIT/TRAIN/DR4/MPEB0/SA1.PHN
# /home/zhihaol/TIMIT/TRAIN/DR4/MRFL0/SA1.PHN
# /home/zhihaol/TIMIT/TRAIN/DR4/MSMC0/SA2.PHN
# /home/zhihaol/TIMIT/TRAIN/DR4/MJPM1/SX401.PHN
# /home/zhihaol/TIMIT/TRAIN/DR4/MGXP0/SI525.PHN
# /home/zhihaol/TIMIT/TRAIN/DR4/MJSR0/SI794.PHN
# /home/zhihaol/TIMIT/TRAIN/DR4/MFWK0/SA2.PHN
# /home/zhihaol/TIMIT/TRAIN/DR4/MBMA0/SX52.PHN
# /home/zhihaol/TIMIT/TRAIN/DR4/MMGC0/SX45.PHN
# /home/zhihaol/TIMIT/TRAIN/DR4/MRSP0/SI2059.PHN
# /home/zhihaol/TIMIT/TRAIN/DR4/MESG0/SA1.PHN
# /home/zhihaol/TIMIT/TRAIN/DR4/MGRP0/SI687.PHN
# /home/zhihaol/TIMIT/TRAIN/DR4/MTAS0/SX125.PHN
# /home/zhihaol/TIMIT/TRAIN/DR4/MJDC0/SX171.PHN
# /home/zhihaol/TIMIT/TRAIN/DR4/MJLB0/SX356.PHN
# /home/zhihaol/TIMIT/TRAIN/DR4/FSSB0/SI1082.PHN
# /home/zhihaol/TIMIT/TRAIN/DR4/MSRG0/SX141.PHN
# /home/zhihaol/TIMIT/TRAIN/DR4/MMDM0/SX141.PHN
# /home/zhihaol/TIMIT/TRAIN/DR4/FJXP0/SX402.PHN
# /home/zhihaol/TIMIT/TRAIN/DR4/MSFH0/SI586.PHN
# /home/zhihaol/TIMIT/TRAIN/DR4/MJMM0/SX175.PHN
# /home/zhihaol/TIMIT/TRAIN/DR4/MDCD0/SX425.PHN
# /home/zhihaol/TIMIT/TRAIN/DR4/MLEL0/SX346.PHN
# /home/zhihaol/TIMIT/TRAIN/DR4/MDMA0/SX80.PHN
# /home/zhihaol/TIMIT/TRAIN/DR4/FLKM0/SX80.PHN
# /home/zhihaol/TIMIT/TRAIN/DR4/MJEE0/SX427.PHN
# /home/zhihaol/TIMIT/TRAIN/DR4/MNET0/SX366.PHN
# /home/zhihaol/TIMIT/TRAIN/DR4/FLHD0/SI1344.PHN
# /home/zhihaol/TIMIT/TRAIN/DR4/MJLS0/SX196.PHN
# /home/zhihaol/TIMIT/TRAIN/DR4/MLJH0/SA2.PHN
# /home/zhihaol/TIMIT/TRAIN/DR4/FKDW0/SX37.PHN
# /home/zhihaol/TIMIT/TRAIN/DR4/FBMJ0/SA1.PHN
# /home/zhihaol/TIMIT/TRAIN/DR4/FCAG0/SA2.PHN
# /home/zhihaol/TIMIT/TRAIN/DR4/FDKN0/SX271.PHN
# /home/zhihaol/TIMIT/TRAIN/DR4/MARW0/SX286.PHN
# /home/zhihaol/TIMIT/TRAIN/DR4/FPAF0/SX64.PHN
# /home/zhihaol/TIMIT/TRAIN/DR4/MJXL0/SX182.PHN
# /home/zhihaol/TIMIT/TRAIN/DR4/MGJC0/SX435.PHN
# /home/zhihaol/TIMIT/TRAIN/DR4/FALR0/SX425.PHN

# %%
abs_fn = "/home/zhihaol/TIMIT/TRAIN/DR2/FDNC0/SA1.wav"
# abs_fn = a
target = train_target
print abs_fn
mfcc_feat = convert_mfcc(abs_fn[:-3] + "wav")
txt_target = read_txt(abs_fn[:-3] + "TXT")
dds = abs_fn.split('/')
new_name = dds[-3] + '_' + dds[-2] + '_' + dds[-1]
new_name = new_name[:-4]
np.save(os.path.join(target, 'mfcc' ,new_name), mfcc_feat.transpose())
#             np.save(os.path.join(target, 'phn' ,new_name), phone_times)
np.save(os.path.join(target, 'txt' ,new_name), txt_target)
# Out:
# /home/zhihaol/TIMIT/TRAIN/DR2/FDNC0/SA1.wav

# %%
a = [[1,2,3],[4,5,6],[7,8,9]]
a = np.asarray(a)
print np.mean(a, 0)
# Out:
# [ 4.  5.  6.]
